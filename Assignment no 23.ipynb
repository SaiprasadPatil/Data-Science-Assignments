# %% [markdown]
# Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of
# Matplotlib.

# %% [markdown]
# Matplotlib is a popular Python library used for creating static, interactive, and animated visualizations in a wide range of formats and styles. It provides a flexible and comprehensive set of tools for generating various types of plots, charts, and graphs to effectively communicate data and insights.
#
# Matplotlib is used for data visualization and exploration in scientific computing, data analysis, machine learning, and other fields. It allows you to create high-quality visualizations for understanding patterns, trends, distributions, and relationships within your data.
#
# The matplotlib.pyplot module, often referred to as Pyplot, is a sub-module of Matplotlib that provides a simple and user-friendly interface for creating basic visualizations. Here are five common types of plots that can be created using the Pyplot module:
#
# Line Plot: Used to display data points connected by straight lines. It's suitable for showing trends or patterns over continuous data.
#
# Scatter Plot: Displays individual data points as dots, useful for visualizing relationships between two variables.
#
# Bar Plot: Represents data using rectangular bars, suitable for comparing quantities of different categories.
#
# Histogram: Shows the distribution of a single variable by dividing it into bins and displaying the frequency of data points in each bin.
#
# Pie Chart: Displays the proportion of each category in a dataset as sectors of a circle, suitable for illustrating parts of a whole.
#
# These are just a few examples, and Matplotlib's capabilities extend far beyond these basic plots. It also supports creating heatmaps, box plots, violin plots, polar plots, 3D plots, and much more. The flexibility and customization options offered by Matplotlib make it a versatile tool for creating a wide variety of visualizations to suit your specific needs.

# %% [markdown]
# Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data
# plot a scatter plot.
# import numpy as np
# np.random.seed(3)
# x = 3 + np.random.normal(0, 2, 50)
# y = 3 + np.random.normal(0, 2, len(x))
# Note: Also add title, xlabel, and ylabel to the plot.

# %% [markdown]
# A scatter plot is a type of data visualization that uses dots to represent individual data points on a two-dimensional plane. It is particularly useful for showing the relationship or correlation between two variables. Each dot on the scatter plot corresponds to a single data point, where one variable is plotted on the x-axis and the other on the y-axis.

# %%
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))
plt.scatter(x, y)

plt.title("Scatter Plot")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")

plt.show()

# %% [markdown]
# Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.
# Use the following data:
# import numpy as np
# For line 1: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([0, 100, 200, 300, 400, 500])
# For line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])
# For line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])
# For line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])

# %% [markdown]
# The subplot() function in Matplotlib is used to create multiple plots within a single figure. It is particularly useful when you want to display multiple plots or charts side by side for easy comparison or visualization. The subplot() function takes three arguments: the number of rows, the number of columns, and the index of the subplot you want to create.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([0, 1, 2, 3, 4, 5])

y1 = np.array([0, 100, 200, 300, 400, 500])
y2 = np.array([50, 20, 40, 20, 60, 70])
y3 = np.array([10, 20, 30, 40, 50, 60])
y4 = np.array([200, 350, 250, 550, 450, 150])

plt.subplot(2, 2, 1)
plt.plot(x, y1)
plt.title('Line Plot 1')

plt.subplot(2, 2, 2)
plt.plot(x, y2)
plt.title('Line Plot 2')

plt.subplot(2, 2, 3)
plt.plot(x, y3)
plt.title('Line Plot 3')

plt.subplot(2, 2, 4)
plt.plot(x, y4)
plt.title('Line Plot 4')

plt.tight_layout()

plt.show()

# %% [markdown]
# Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.
# import numpy as np
# company = np.array(["Apple", "Microsoft", "Google", "AMD"])
# profit = np.array([3000, 8000, 1000, 10000])

# %% [markdown]
# A bar plot is a type of data visualization that uses rectangular bars to represent data. It is used to compare and display the values of different categories or groups. In a bar plot, the length or height of each bar corresponds to the value of the data it represents. Bar plots are particularly useful for comparing the magnitude of different data points or showing patterns and trends in categorical data.
#
# A horizontal bar plot is similar to a bar plot, but the bars are oriented horizontally instead of vertically. This orientation can be useful when you have long labels or want to emphasize differences in values.

# %%
import numpy as np
import matplotlib.pyplot as plt

company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

plt.figure(figsize=(8, 6)) 
plt.bar(company, profit, color='blue')
plt.title("Company Profits")
plt.xlabel("Company")
plt.ylabel("Profit")
plt.show()

# %%
plt.figure(figsize=(8, 6))  
plt.barh(company, profit, color='green')
plt.title("Company Profits (Horizontal)")
plt.xlabel("Profit")
plt.ylabel("Company")
plt.show()

# %% [markdown]
# Q5: What is a box plot? Why is it used? Using the following data plot a box plot.
# box1 = np.random.normal(100, 10, 200)
# box2 = np.random.normal(90, 20, 200)

# %% [markdown]
# A box plot, also known as a box-and-whisker plot, is a type of data visualization that displays the distribution of a dataset using a five-number summary: the minimum, first quartile (Q1), median, third quartile (Q3), and maximum. The "box" in the plot represents the interquartile range (IQR), which is the range between Q1 and Q3, while the "whiskers" extend from the box to the minimum and maximum values within a certain range (often 1.5 times the IQR). Outliers, if present, are usually shown as individual points beyond the whiskers.
#
# Box plots are used to provide a visual summary of the distribution of data, including information about central tendency, spread, skewness, and potential outliers. They are especially useful for comparing distributions between multiple groups or datasets.

# %%
import numpy as np
import matplotlib.pyplot as plt

box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)

plt.figure(figsize=(8, 6)) 
plt.boxplot([box1, box2], labels=['Box 1', 'Box 2'])
plt.title("Box Plot")
plt.xlabel("Box")
plt.ylabel("Values")
plt.show()
